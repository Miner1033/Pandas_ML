# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\miner\Python_Pandas\fortune10missing.csv - Sheet1.csv')
df
# Out:
#    ID             Name             Industry  Inception   Revenue  \
# 0   1          Lamtone          IT Services       2009  ########
# 1   2        Stripfind   Financial Services       2010  ########
# 2   3  Canecorporation               Health       2012  ########
# 3   4         Mattouch          IT Services       2013  ########
# 4   5        Techdrill               Health       2009  ########
# 5   6         Techline               Health       2006  ########
# 6   7          Cityace               Health       2010  ########
# 7   8   Kayelectronics               Health       2009  ########
# 8   9          Ganzlax          IT Services       2011  ########
# 9  10      Trantraxlax  Government Services       2011  ########
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    NaN
# 4  7,435,363 Dollars   3138627    NaN
# ...

# %% [raw]
# #N/A
# #N/A N/A
# #NA
# -1.#IND
# -1.#QNAN
# -Nan
# nan
# N/A
# NA
# NULL
# null
# n/a
# nan
# 1.#IND
# 1.#QNAN

# %%
df=pd.read_csv(r'C:\Users\miner\Python_Pandas\fortune10missing.csv - Sheet1.csv',na_filter=False)
df
# Out:
#    ID             Name             Industry  Inception   Revenue  \
# 0   1          Lamtone          IT Services       2009  ########
# 1   2        Stripfind   Financial Services       2010  ########
# 2   3  Canecorporation               Health       2012  ########
# 3   4         Mattouch          IT Services       2013  ########
# 4   5        Techdrill               Health       2009  ########
# 5   6         Techline               Health       2006  ########
# 6   7          Cityace               Health       2010  ########
# 7   8   Kayelectronics               Health       2009  ########
# 8   9          Ganzlax          IT Services       2011  ########
# 9  10      Trantraxlax  Government Services       2011  ########
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557
# 4  7,435,363 Dollars   3138627
# ...

# %%
df['Growth'] = df['Growth'].fillna(df['Growth'].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df['Growth'] = df['Growth'].fillna(df['Growth'].mean())
#       2 df
#
# File D:\Python\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File D:\Python\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# ...
